# %%
# import dependencies
import requests
import pandas as pd
import numpy as np
from config import api_key
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
movie_list = pd.read_csv('resources/cleaned/movie_list_cleaned.csv')

# %%
movie_list = movie_list.dropna(subset=['name'])

movie_list.head()
# Out:
#                        Title  Release date         Time Period  Start Time  \
# 0             Quest for Fire          1981           80,000 BC      -80000
# 1               Homo Erectus          2007            50000 BC      -50000
# 3  The Clan of the Cave Bear          1986  40,000 - 35,000 BC      -40000
# 4                      Alpha          2018           20,000 BC      -20000
# 5                  10,000 BC          2008           10,000 BC      -10000
#
#    End Time Location         genre_ids  movie_id original_language  \
# 0    -80000   Europe          [12, 18]     62204                fr
# 1    -50000   Europe              [35]     14641                en
# 3    -40000   Europe          [12, 18]     13853                en
# 4    -20000   Europe          [12, 18]    399360                en
# 5    -10000   Europe  [12, 28, 18, 14]      7840                en
#
#                                             overview  ...  \
# 0  A colossal adventure odyssey that turns back t...  ...
# 1  Ishbo is a caveman living in the prehistoric a...  ...
# 3  Natural changes have the clans moving. Iza, me...  ...
# 4  In the prehistoric past, Keda, a young and ine...  ...
# 5  A prehistoric epic that follows a young mammot...  ...
#
#                        title  video  vote_average  vote_count  \
# 0             Quest for Fire  False           7.1       364.0
# 1               Homo Erectus  False           3.9        25.0
# 3  The Clan of the Cave Bear  False           5.1        88.0
# 4                      Alpha  False           6.4      2112.0
# 5                  10,000 BC  False           5.4      2406.0
#
#                                         genres  \
# 0                       ['Adventure', 'Drama']
# 1                                   ['Comedy']
# 3                       ['Adventure', 'Drama']
# 4                       ['Adventure', 'Drama']
# 5  ['Adventure', 'Action', 'Drama', 'Fantasy']
#
#                                                 name  \
# 0  Everett McGill, Ron Perlman, Nicholas Kadi, Ra...
# 1  Sasha Grey, David Carradine, Carol Alt, Talia ...
# 3  Daryl Hannah, Pamela Reed, James Remar, Thomas...
# 4  Kodi Smit-McPhee, Jóhannes Haukur Jóhannesson,...
# 5  Steven Strait, Camilla Belle, Cliff Curtis, Na...
#
#                                             keywords Full Location latitude  \
# 0  fire, based on novel or book, mammoth, stone a...        أوروبا     51.0
# 1          national lampoon serie, prehistoric times        أوروبا     51.0
# 3  stone age, animal attack, tribe, bear, cavemen...        أوروبا     51.0
# 4  wolf, ice age, human animal relationship, wild...        أوروبا     51.0
# 5  hunter, indigenous, lover (female), pyramid, m...        أوروبا     51.0
#
#    longitude
# 0       10.0
# 1       10.0
# 3       10.0
# 4       10.0
# 5       10.0
#
# [5 rows x 21 columns]

# %%
movie_list.to_csv('resources/cleaned/movie_list_cleaned.csv', index=False)
