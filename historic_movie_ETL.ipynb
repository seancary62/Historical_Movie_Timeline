# %%
# import dependencies
import requests
import pandas as pd
from config import api_key

# %%
movie_1 = pd.DataFrame(requests.get(f'https://api.themoviedb.org/3/search/movie?api_key={api_key}&query=Les+Misérables').json()['results'])
movie_1.head()
# Out:
#    adult                     backdrop_path            genre_ids      id  \
# 0  False  /nU6Xptg0KVxuVx737W5bvmP8wmg.jpg             [36, 18]   82695
# 1  False  /6K74rGGGjKGrblGTa7S9yRcUtnF.jpg         [80, 18, 53]  586863
# 2  False  /4ndvn7UVMboDatqPFpFTJ2PTl5u.jpg             [18, 36]    4412
# 3  False  /nHObruulobpKEjLygJxvgH2DTzM.jpg  [80, 18, 36, 10749]    4415
# 4  False  /yCOBE5pBbyKLYkDjPGi5qa1sSGW.jpg             [18, 36]    4416
#
#   original_language  original_title  \
# 0                en  Les Misérables
# 1                fr  Les Misérables
# 2                fr  Les Misérables
# 3                en  Les Misérables
# 4                fr  Les Misérables
#
#                                             overview  popularity  \
# 0  An adaptation of the successful stage musical ...      21.530
# 1  Inspired by the 2005 riots in Paris, Stéphane,...      17.153
# 2  Victor Hugo's monumental novel Les Miserables ...       8.025
# ...

# %%
#Get wiki movie list data
movie_list = pd.read_csv('resources/wiki_movie_list.csv')

# %%
movie_list.head()
# Out:
#                         Title Release date     Time Era         Time Period  \
# 0                   Early Man         2018  Paleolithic      1 Million B.C.
# 1              Quest for Fire         1981  Paleolithic           80,000 BC
# 2   The Clan of the Cave Bear         1986  Paleolithic  40,000 � 35,000 BC
# 3                       Alpha         2018  Paleolithic           20,000 BC
# 4  Creatures the World Forgot         1971  Paleolithic                 NaN
#
#                                     Notes on setting Location
# 0  Stop motion animated comedy about a group of c...   Europe
# 1  The story is set in Paleolithic Europe, with i...   Europe
# 2                 In times of�Neanderthal extinction   Europe
# 3                                  Dog domestication   Europe
# 4                                                NaN   Europe

# %%
movie_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1139 entries, 0 to 1138
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             1139 non-null   object
#  1   Release date      1139 non-null   object
#  2   Time Era          691 non-null    object
#  3   Time Period       860 non-null    object
#  4   Notes on setting  911 non-null    object
#  5   Location          1135 non-null   object
# dtypes: object(6)
# memory usage: 53.5+ KB

# %%
movie_list.dropna(subset=['Time Period'], inplace=True)
movie_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 1138
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             860 non-null    object
#  1   Release date      860 non-null    object
#  2   Time Era          688 non-null    object
#  3   Time Period       860 non-null    object
#  4   Notes on setting  833 non-null    object
#  5   Location          856 non-null    object
# dtypes: object(6)
# memory usage: 47.0+ KB
