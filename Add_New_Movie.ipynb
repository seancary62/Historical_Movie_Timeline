# %% [markdown]
# # Add New Movies to the Cleaned Movie List

# %%
# import dependencies
import requests
import pandas as pd
from config import api_key
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
# Read cleaned movie list
wiki_movie_list = pd.read_csv('resources/cleaned/movie_list_cleaned.csv')
wiki_movie_list.head()
# Out:
#                        Title  Release date         Time Period  Start Time  \
# 0             Quest for Fire          1981           80,000 BC      -80000
# 1  The Clan of the Cave Bear          1986  40,000 - 35,000 BC      -40000
# 2        Conan the Barbarian          1982  32,000 - 10,000 BC      -32000
# 3        Conan the Destroyer          1984  32,000 - 10,000 BC      -32000
# 4                      Alpha          2018           20,000 BC      -20000
#
#    End Time                                   Notes on setting     Location  \
# 0    -80000  The story is set in Paleolithic Europe, with i...       Europe
# 1    -35000                 In times of�Neanderthal extinction       Europe
# 2    -10000  Occurs in the pseudo-historical "Hyborian Age"...  Middle East
# 3    -10000                                                NaN  Middle East
# 4    -20000                                  Dog domestication       Europe
#
# ...

# %%
# Add New Movie

# Information below needs to be included:
title = 'holder'
release_date = 'date'
time_period = 'length'
start_time = 'begin year'
end_time = 'end year'
location = 'location'
