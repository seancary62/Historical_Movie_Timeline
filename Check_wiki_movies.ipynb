# %%
# import dependencies
import requests
import pandas as pd
import re
from config import api_key

# %%
#Get wiki movie list data
movie_list = pd.read_csv('resources/wiki_movie_list.csv')

for ind in movie_list.index:
    movie=movie_list['Title'][ind]
    year=movie_list['Release date'][ind]
    print(year)
# movie = 'Les Misérables'
# year = movie_list.loc[movie_list['Title'] == movie, 'Release date'].values[1]
print(year)
# movie = movie.replace(' ','+')

# start = movie.find('(')
# end = movie.find(')')+1

# sub = movie[start:end]

# movie = movie.replace(sub,'')

# movie_1 = pd.DataFrame(requests.get(f'https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={movie}').json()['results'])
# movie_1.head()
# Out:
# 1909
# 1911
# 1916
# 1917
# 1921
# 1922
# 1923
# 1924
# 1926
# 1927
# 1927
# 1927
# 1928
# 1928
# 1930
# 1930
# 1931
# 1932
# 1932
# 1933
# 1933
# 1934
# 1934
# 1934
# 1934
# 1934
# 1934
# 1934
# 1934
# 1935
# 1935
# 1935
# 1935
# 1935
# 1935
# 1935
# 1935
# 1935
# 1935
# 1936
# 1936
# 1936
# 1936
# 1936
# 1937
# 1937
# 1937
# 1937
# 1937
# 1937
# 1937
# 1938
# 1938
# 1938
# 1938
# 1939
# 1939
# 1939
# 1939
# 1939
# 1939
# 1939
# 1939
# 1939
# 1939
# 1940
# 1940
# 1940
# 1941
# 1941
# 1941
# 1941
# 1942
# 1943
# 1944
# 1945
# 1945
# 1945
# 1945
# 1946
# 1946
# 1946
# 1947
# 1947
# 1947
# 1948
# 1948
# 1948
# 1949
# 1949
# 1949
# 1950
# 1950
# 1950
# 1950
# 1950
# 1950
# 1950
# 1950
# 1950
# 1950
# 1950
# 1951
# 1951
# 1951
# 1951
# 1951
# 1951
# 1951
# 1951
# 1952
# 1952
# 1952
# 1952
# 1952
# 1952
# 1952
# 1953
# 1953
# 1953
# 1953
# 1953
# 1953
# 1953
# 1953
# 1953
# 1953
# 1953
# 1954
# 1954
# 1954
# 1954
# 1954
# 1954
# 1954
# 1954
# 1954
# 1954
# 1954
# 1954
# 1954
# 1954
# ...

# %%
#Get wiki movie list data
movie_list = pd.read_csv('resources/wiki_movie_list.csv')

# %%
movie_list.head()
# Out:
#                                               Title Release date Time Era  \
# 0                                            Aguila         1980      NaN
# 1  Tirad Pass: The Story of Gen. Gregorio del Pilar         1997      NaN
# 2                                      Heneral Luna         2015      NaN
# 3                                  Tiniente Rosario         1937      NaN
# 4                                             Baler         2008      NaN
#
#         Time Period  Start Time  End Time  Diff  \
# 0         1899-1945        1899      1945    46
# 1  December 2, 1899        1899      1899     0
# 2         1898-1903        1898      1903     5
# 3         1898-1901        1898      1901     3
# 4              1898        1898      1898     0
#
#                                     Notes on setting     Location
# 0                                 Philippine history  Philippines
# 1  About the�Battle of Tirad Pass, Philippine Cam...  Philippines
# ...

# %%
movie_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1136 entries, 0 to 1135
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             1136 non-null   object
#  1   Release date      1136 non-null   object
#  2   Time Era          688 non-null    object
#  3   Time Period       1136 non-null   object
#  4   Start Time        1136 non-null   int64
#  5   End Time          1136 non-null   int64
#  6   Diff              1136 non-null   int64
#  7   Notes on setting  909 non-null    object
#  8   Location          1132 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 80.0+ KB

# %%
movie_list.dropna(subset=['Time Period'], inplace=True)
movie_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1136 entries, 0 to 1135
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             1136 non-null   object
#  1   Release date      1136 non-null   object
#  2   Time Era          688 non-null    object
#  3   Time Period       1136 non-null   object
#  4   Start Time        1136 non-null   int64
#  5   End Time          1136 non-null   int64
#  6   Diff              1136 non-null   int64
#  7   Notes on setting  909 non-null    object
#  8   Location          1132 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 88.8+ KB

# %%
movie_1 = pd.DataFrame(requests.get(f'https://api.themoviedb.org/3/search/movie?api_key={api_key}&year=1958&query=Les+Misérables').json()['results'])
movie_1.head()

# %%
movie = 'The Liberator'

movie = movie.replace(' ','+')

start = movie.find('(')
end = movie.find(')')+1

sub = movie[start:end]

movie = movie.replace(sub,'')

movie_1 = pd.DataFrame(requests.get(f'https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={movie}').json()['results'])
movie_1.head()
